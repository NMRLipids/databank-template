# %% [markdown]
# ### You can run this notebook at Colab by clicking here:

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/NMRLipids/databank-template/blob/museum/scripts/plotQuality.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>

# %% [markdown]
# # Show ranking tables of simulations against experimental data
#
# This notebook shows different kinds of rankings of simulations against experimental data.
# This reading ranking tables from `Data/Ranking/` folder.
# Before using this, run `python makeRanking.py` in `Scripts/BuildDatabank` folder.

# %% [markdown]
# # Initialize NMRlipids databank

# %%
# This installs NMRlipids Databank on COLAB environment,
# you can use the same commands on your local machine if you run it locally.

import sys
import os

os.environ["NMLDB_ROOT_PATH"] = os.path.abspath(".." + os.sep + ".." + os.sep + "Databank")

if 'google.colab' in sys.modules:
    # !git clone https://github.com/NMRlipids/MuseumDatabank
    # %cd Databank
    # !sed -i '/numpy/s/^/# /' Scripts/DatabankLib/requirements.txt
    # !pip3 install .
    os.environ["NMLDB_ROOT_PATH"] = "/content/Databank"

# %%
# These two lines include core Databank routines and Databank API
from DatabankLib import *
from DatabankLib.core import *
from DatabankLib.databankLibrary import *
# this is for showing statistics tables
from DatabankLib.jpyroutines import showTable

# This initializes the databank and stores the information of all simulations into a list.
# Each list item contains the information from README.yaml file of the given simulation.
systems = initialize_databank()
# Out:
# Databank initialized from the folder: /big/comcon1/repo/Databank/Data/Simulations

# %% [markdown]
# # Show ranking of simulations based on total quality, tail quality and headgroup quality

# %%
Fragments = ['total','tails','headgroup','FormFactor']

for SortBasedOn in Fragments:
    print('Sorted based on ', SortBasedOn, ' quality')

    FFrankingPath = os.path.join(
        NMLDB_ROOT_PATH,
        'Data', 'Ranking',
        f'SYSTEM_{SortBasedOn}_Ranking.json')

    with open(FFrankingPath) as json_file:
        FFranking = json.load(json_file)

    showTable(FFranking, 'TotalQuality')
# Out:
# Sorted based on  total  quality
# **FAILURE:** no FF defined for the system
# 'c04/cdb/c04cdb61143bb72ba2ddee11599e6bbfaf6cb211/a31f42800216d84d2242eae2af8ac2cbd6b033ee/'
# **FAILURE:** no FF defined for the system
# 'a7f/9f3/a7f9f36feaa77791483dadb0157f86a6a519f2c3/a30f01e8771c44dc59b78753d1dd27ca67920e38/'
#      headgroup  tails  total  \
# 0         0.70   0.87   0.81
# 1         0.70   0.87   0.81
# 2         0.73   0.84   0.81
# 3         0.73   0.84   0.80
# 4         0.70   0.85   0.80
# 5         0.71   0.80   0.77
# 6         0.75   0.78   0.77
# 7         0.66   0.74   0.72
# 8         0.68   0.72   0.71
# 9         0.67   0.71   0.70
# 10        0.62   0.73   0.69
# 11        0.57   0.72   0.67
# 12        0.63   0.69   0.67
# 13        0.56   0.72   0.67
# 14        0.62   0.69   0.67
# 15        0.60   0.70   0.66
# 16        0.69   0.64   0.66
# 17        0.66   0.66   0.66
# 18        0.49   0.73   0.65
# 19        0.69   0.63   0.65
# 20        0.65   0.65   0.65
# 21        0.61   0.66   0.64
# 22        0.59   0.67   0.64
# 23        0.66   0.63   0.64
# 24        0.78   0.55   0.63
# 25        0.69   0.59   0.62
# 26        0.64   0.61   0.62
# 27        0.66   0.60   0.62
# 28        0.56   0.62   0.60
# 29        0.62   0.59   0.60
# 30        0.64   0.57   0.59
# 31        0.63   0.57   0.59
# 32        0.60   0.57   0.58
# 33        0.59   0.56   0.57
# 34        0.59   0.55   0.56
# 35        0.30   0.69   0.56
# 36        0.55   0.56   0.56
# 37        0.64   0.51   0.56
# 38        0.66   0.50   0.55
# 39        0.29   0.65   0.53
# 40        0.30   0.65   0.53
# 41        0.01   0.78   0.52
# 42        0.10   0.72   0.51
# 43        0.10   0.71   0.51
# 44        0.03   0.73   0.50
# 45        0.16   0.66   0.50
# 46        0.01   0.73   0.49
# 47        0.28   0.57   0.48
# 48        0.65   0.38   0.47
# 49        0.54   0.40   0.44
# 50        0.21   0.55   0.44
# 51        0.68   0.29   0.42
# 52        0.69   0.29   0.42
# 53        0.67   0.29   0.42
# 54        0.15   0.55   0.41
# 55        0.13   0.55   0.41
# 56        0.67   0.27   0.40
# 57        0.02   0.58   0.39
# 58        0.64   0.27   0.39
# 59        0.32   0.41   0.38
# 60        0.27   0.43   0.37
# 61        0.57   0.27   0.37
# 62        0.58   0.26   0.37
# 63        0.00   0.17   0.34
# 64        0.39   0.31   0.34
# 65        0.20   0.39   0.33
# 66        0.63   0.18   0.33
# 67        0.04   0.44   0.30
# 68        0.66   0.12   0.30
# 69        0.63   0.13   0.30
# 70        0.06   0.41   0.29
# 71        0.60   0.14   0.29
# 72        0.06   0.40   0.29
# 73        0.02   0.40   0.27
# 74        0.53   0.11   0.25
# 75        0.12   0.29   0.23
# 76        0.37   0.15   0.23
# 77        0.15   0.26   0.22
# 78        0.18   0.20   0.21
# 79        0.09   0.24   0.19
# 80        0.11   0.21   0.18
# 81        0.21   0.17   0.18
# 82        0.26   0.12   0.17
# 83        0.14   0.19   0.17
# 84        0.14   0.17   0.16
# 85        0.07   0.19   0.15
# 86        0.26   0.07   0.13
# 87        0.22   0.09   0.13
# 88        0.19   0.07   0.11
# 89        0.17   0.07   0.10
# 90        0.18   0.04   0.08
# 91        0.02   0.09   0.08
# 92        0.04   0.07   0.06
# 93        0.13   0.03   0.06
# 94        0.11   0.03   0.05
# 95        0.08   0.02   0.04
# 96        0.01   0.02   0.02
# 97        0.00   0.00   0.00
# 98        0.00   0.00   0.00
# 99        0.00   0.00   0.00
# 100       0.00   0.00   0.00
# 101       0.00   0.00   0.00
# 102       0.00   0.00   0.00
# 103       0.00   0.00   0.00
#
#                                            Forcefield          Molecules  \
# 0                                               OPLS4           POPC:SOL
# 1                                              OPLS3e           POPC:SOL
# 2                                              OPLS3e           POPC:SOL
# 3                                               OPLS4           POPC:SOL
# 4                                               OPLS4           POPC:SOL
# 5                                               OPLS4           POPC:SOL
# 6                                              OPLS3e           POPC:SOL
# 7                                  C36_Slipids_Hybrid           POPC:SOL
# 8                                               OPLS4           POPC:SOL
# 9                                              MacRog           POPC:SOL
# 10                                            Slipids           POPC:SOL
# 11                                            Lipid17           POPC:SOL
# 12                                             MacRog           POPC:SOL
# 13                                            Lipid17           POPC:SOL
# 14                                           CHARMM36           POPC:SOL
# 15                                             MacRog           POPC:SOL
# 16                                           CHARMM36           DMPC:SOL
# 17                                             MacRog           POPC:SOL
# 18                                            Lipid17           POPC:SOL
# 19                                           CHARMM36           POPC:SOL
# 20                                           CHARMM36           DMPC:SOL
# 21                                             MacRog           POPC:SOL
# 22                                            Slipids           POPC:SOL
# 23                                 C36_Slipids_Hybrid           POPC:SOL
# 24                                              OPLS4           DMPC:SOL
# 25                                              OPLS4           DMPC:SOL
# 26                                           CHARMM36           DOPC:SOL
# 27                                              OPLS4           DMPC:SOL
# 28                                            Slipids           POPC:SOL
# 29                                             MacRog           POPC:SOL
# 30                                           CHARMM36           DOPC:SOL
# 31                                             OpenFF           POPC:SOL
# 32                                             AMOEBA           DOPC:SOL
# 33                                             OpenFF           POPC:SOL
# 34                                             OpenFF           POPC:SOL
# 35                       Charmm-Drude polarizable2023           POPE:SOL
# 36                                            Slipids           POPC:SOL
# 37                                           CHARMM36           DOPC:SOL
# 38                                         ECC-lipids           POPC:SOL
# 39                                         GROMOS-CKP           POPE:SOL
# 40                       Charmm-Drude polarizable2023           POPE:SOL
# 41                                            Slipids           POPE:SOL
# 42                                            Slipids           POPE:SOL
# 43                                            Slipids           POPE:SOL
# 44                                             Berger           POPC:SOL
# 45              ECC-lipids, SPC water model, ECC-ions       POPS:SOL:SOD
# 46                                             Berger           POPC:SOL
# 47                       Charmm-Drude polarizable2023           POPE:SOL
# 48                                         ECC-lipids           POPC:SOL
# 49                                           CHARMM36           SOL:POPE
# 50        GROMOS-CKP, Berger/Chiu NH3 charges and PME       POPS:SOL:SOD
# 51                                           CHARMM36           POPC:SOL
# 52                                           CHARMM36           POPC:SOL
# 53                                           CHARMM36           POPC:SOL
# 54             GROMOS-CKP, GROMOS NH3 charges and PME       POPS:SOL:SOD
# 55             GROMOS-CKP, GROMOS NH3 charges and PME       POPS:SOL:SOD
# 56                                           CHARMM36           POPC:SOL
# 57   Berger and Modified Höltje model for cholesterol      POPC:CHOL:SOL
# 58                                           CHARMM36           POPC:SOL
# 59                                        CHARMM36-UA           POPE:SOL
# 60                                        CHARMM36-UA           POPE:SOL
# 61                                           CHARMM36           POPC:SOL
# 62                         Lipid14 with Verlet scheme           POPC:SOL
# 63                                           Charmm36           SM16:SOL
# 64                                             MacRog           POPC:SOL
# 65        GROMOS-CKP, Berger/Chiu NH3 charges and PME       POPS:SOL:SOD
# 66                                           Charmm36           POPC:SOL
# 67                 Berger delivered by Peter Tieleman           POPC:SOL
# 68                                           CHARMM36           DMPC:SOL
# 69                                           Charmm36           DMPC:SOL
# 70                                             Orange           POPC:SOL
# 71                                           Charmm36           DMPC:SOL
# 72                                       Charmm-Drude           POPE:SOL
# 73   Berger and Modified Höltje model for cholesterol      POPC:CHOL:SOL
# 74                                           CHARMM36           SOL:POPE
# 75                                            Slipids       POPG:SOL:SOD
# 76                                           Charmm36           POPE:SOL
# 77                                        Chiu Gromos           POPC:SOL
# 78                                            slipids      CHOL:POPC:SOL
# 79                                            Lipid17           POPE:SOL
# 80                                            Slipids       POPS:SOL:SOD
# 81                                             AMOEBA           POPE:SOL
# 82                                        CHARMM36-UA       POPS:SOL:SOD
# 83                              Lipid17 and ff99 ions       POPS:SOL:SOD
# 84                                            Slipids       POPS:SOL:SOD
# 85                                         GROMOS-CKP           POPC:SOL
# 86                                           CHARMM36       POPS:SOL:SOD
# 87                                        CHARMM36-UA       POPS:SOL:SOD
# 88                                             MacRog       POPS:SOL:SOD
# 89                                             MacRog       POPS:SOL:SOD
# 90                                           CHARMM36       POPS:SOL:SOD
# 91   Berger and Modified Höltje model for cholesterol      POPC:CHOL:SOL
# 92   Berger and Modified Höltje model for cholesterol      POPC:CHOL:SOL
# 93                                             Berger       POPS:SOL:SOD
# 94                                             Berger       POPS:SOL:SOD
# 95                              Lipid17 and Dang ions       POPS:SOL:SOD
# 96   Berger and Modified Höltje model for cholesterol      POPC:CHOL:SOL
# 97                                            Lipid17  POPC:POPG:SOL:SOD
# 98                                           CHARMM36  POPG:POPC:SOL:SOD
# 99                                         lipid17ecc  POPG:POPC:SOL:SOD
# 100                                           Slipids  POPC:POPG:SOD:SOL
# 101                                        lipid17ecc  POPG:POPC:SOL:SOD
# 102                                          CHARMM36  POPG:POPC:SOL:SOD
# 103                                           lipid17  POPG:POPC:SOL:SOD
#
#       Number of molecules  Temperature   ID  FFQuality
# 0              (200:4000)       300.00  803        NaN
# 1              (200:4000)       300.00  815        NaN
# 2              (200:8859)       300.00  805       0.15
# 3              (200:9000)       300.00  814       0.15
# 4              (200:2400)       300.00  804        NaN
# 5              (200:1500)       300.00  802        NaN
# 6              (200:1000)       300.00  796        NaN
# 7              (128:6400)       298.00  830       0.76
# 8              (200:1000)       300.00  817        NaN
# 9            (1024:51200)       298.15  658       0.65
# 10            (512:23943)       298.00  617       0.46
# 11           (1024:51200)       298.15  684       0.24
# 12             (128:5120)       300.00  457       0.55
# 13            (256:12800)       298.15  657       0.24
# 14             (200:2400)       300.00  798        NaN
# 15              (64:3200)       298.15  674       0.55
# 16             (200:1000)       314.00  800        NaN
# 17            (256:12800)       298.15  675       0.55
# 18              (64:3200)       298.15  715       0.14
# 19             (200:1500)       300.00  806        NaN
# 20             (200:2000)       314.00  809        NaN
# 21             (288:5760)       298.00  606        NaN
# 22           (1024:51200)       298.15  696       0.46
# 23             (128:6400)       298.00  831       0.95
# 24             (200:2000)       314.00  810        NaN
# 25             (200:1000)       314.00  811        NaN
# 26           (1024:51200)       303.15   47       0.92
# 27             (200:9000)       314.00  813        NaN
# 28            (256:12800)       298.15  708       0.56
# 29            (288:14400)       298.00   63       0.55
# 30            (256:12800)       303.15  551       0.92
# 31             (128:5120)       300.00  797       1.05
# 32              (72:2880)       303.00  742        NaN
# 33             (128:5000)       300.00  761       1.75
# 34             (128:5000)       300.00  792       2.06
# 35              (72:2304)       308.00  747       0.30
# 36              (64:3200)       298.15  664       0.76
# 37              (64:3200)       303.15  316       1.02
# 38             (128:6400)       300.00  573       0.56
# 39            (500:25000)       310.00  400       0.40
# 40              (72:2304)       308.00  750       0.20
# 41            (500:25000)       310.00  414       0.10
# 42            (336:13460)       310.00   29        NaN
# 43            (336:13460)       310.00   74        NaN
# 44             (128:7290)       298.00  497       1.04
# 45           (72:3600:72)       298.00  443       0.40
# 46            (256:10342)       300.00  115       0.94
# 47              (72:2304)       308.00  751       0.00
# 48             (128:6400)       300.00   43       0.76
# 49             (5760:144)       310.00  430       1.30
# 50         (128:4480:128)       298.00  597       0.80
# 51             (256:9767)       300.00  558       1.25
# 52           (1024:51200)       298.15  701       1.25
# 53             (200:8880)       300.00  164       1.25
# 54         (128:4480:128)       298.00  425       0.80
# 55         (128:4480:128)       298.00  473       0.60
# 56            (256:12800)       298.15  710       1.25
# 57           (120:8:7290)       298.00  305       0.75
# 58              (64:3200)       298.15  678       1.46
# 59            (336:15254)       310.00  352       0.30
# 60            (336:15254)       310.00  233       0.30
# 61              (64:3200)       298.15  546       1.55
# 62             (128:5120)       298.15   30       0.85
# 63             (200:9000)       328.15  765       2.00
# 64             (288:1440)       298.00  378        NaN
# 65         (128:4480:128)       298.00  535       0.70
# 66             (200:1000)       300.00  795        NaN
# 67              (128:896)       298.00  128        NaN
# 68            (200:10000)       314.00  808        NaN
# 69              (64:3200)       313.15  789        NaN
# 70              (72:2880)       298.00   38       0.26
# 71              (64:3200)       313.15  788        NaN
# 72             (144:5040)       310.00  731       0.80
# 73          (110:18:8481)       298.00  589       0.27
# 74            (25000:500)       310.00   67       1.70
# 75        (288:10664:288)       298.00  207        NaN
# 76             (144:5760)       310.00  790       2.00
# 77             (128:3552)       298.00  422       0.76
# 78        (256:256:20334)       298.00   82       3.39
# 79            (500:25000)       310.00  195       1.60
# 80         (128:4480:128)       298.00  529       0.30
# 81              (72:2880)       310.00  730       3.80
# 82         (128:4480:128)       298.00  263       0.80
# 83           (72:3600:72)       298.00  521       0.80
# 84         (128:4480:128)       298.00  338       0.40
# 85            (500:25000)       298.00  202       1.35
# 86         (128:4480:128)       298.00    5       1.70
# 87         (128:4480:128)       298.00  367       1.20
# 88         (128:4480:128)       298.00  292       1.80
# 89         (128:4480:128)       298.00   26       1.60
# 90         (128:4480:128)       298.00  106       2.20
# 91          (64:64:10314)       298.00  299       1.29
# 92           (84:44:6794)       298.00  206       0.33
# 93         (128:4480:128)       298.00  502       2.40
# 94         (128:4480:128)       298.00  480       2.30
# 95           (72:3600:72)       298.00  483       2.10
# 96           (50:78:5782)       298.00   15        NaN
# 97    (150:150:31572:150)       298.00  503        NaN
# 98      (88:350:26280:88)       298.00   58        NaN
# 99    (150:150:29865:150)       298.00  146        NaN
# 100   (128:128:128:12800)       298.00  307        NaN
# 101     (88:350:26265:88)       298.00  429        NaN
# 102   (150:150:31500:150)       298.00  592        NaN
# 103     (88:350:26265:88)       298.00  317        NaN
# Sorted based on  tails  quality
# **FAILURE:** no FF defined for the system
# 'c04/cdb/c04cdb61143bb72ba2ddee11599e6bbfaf6cb211/a31f42800216d84d2242eae2af8ac2cbd6b033ee/'
# **FAILURE:** no FF defined for the system
# 'a7f/9f3/a7f9f36feaa77791483dadb0157f86a6a519f2c3/a30f01e8771c44dc59b78753d1dd27ca67920e38/'
#     headgroup  tails  total                                        Forcefield  \
# 0        0.70   0.87   0.81                                             OPLS4
# 1        0.70   0.87   0.81                                            OPLS3e
# 2        0.70   0.85   0.80                                             OPLS4
# 3        0.73   0.84   0.81                                            OPLS3e
# 4        0.73   0.84   0.80                                             OPLS4
# 5        0.71   0.80   0.77                                             OPLS4
# 6        0.75   0.78   0.77                                            OPLS3e
# 7        0.01   0.78   0.52                                           Slipids
# 8        0.66   0.74   0.72                                C36_Slipids_Hybrid
# 9        0.01   0.73   0.49                                            Berger
# 10       0.03   0.73   0.50                                            Berger
# 11       0.49   0.73   0.65                                           Lipid17
# 12       0.62   0.73   0.69                                           Slipids
# 13       0.57   0.72   0.67                                           Lipid17
# 14       0.68   0.72   0.71                                             OPLS4
# 15       0.56   0.72   0.67                                           Lipid17
# 16       0.10   0.72   0.51                                           Slipids
# 17       0.10   0.71   0.51                                           Slipids
# 18       0.67   0.71   0.70                                            MacRog
# 19       0.60   0.70   0.66                                            MacRog
# 20       0.30   0.69   0.56                      Charmm-Drude polarizable2023
# 21       0.62   0.69   0.67                                          CHARMM36
# 22       0.63   0.69   0.67                                            MacRog
# 23       0.59   0.67   0.64                                           Slipids
# 24       0.16   0.66   0.50             ECC-lipids, SPC water model, ECC-ions
# 25       0.66   0.66   0.66                                            MacRog
# 26       0.61   0.66   0.64                                            MacRog
# 27       0.29   0.65   0.53                                        GROMOS-CKP
# 28       0.65   0.65   0.65                                          CHARMM36
# 29       0.30   0.65   0.53                      Charmm-Drude polarizable2023
# 30       0.69   0.64   0.66                                          CHARMM36
# 31       0.69   0.63   0.65                                          CHARMM36
# 32       0.66   0.63   0.64                                C36_Slipids_Hybrid
# 33       0.56   0.62   0.60                                           Slipids
# 34       0.64   0.61   0.62                                          CHARMM36
# 35       0.66   0.60   0.62                                             OPLS4
# 36       0.69   0.59   0.62                                             OPLS4
# 37       0.62   0.59   0.60                                            MacRog
# 38       0.02   0.58   0.39  Berger and Modified Höltje model for cholesterol
# 39       0.60   0.57   0.58                                            AMOEBA
# 40       0.28   0.57   0.48                      Charmm-Drude polarizable2023
# 41       0.63   0.57   0.59                                            OpenFF
# 42       0.64   0.57   0.59                                          CHARMM36
# 43       0.55   0.56   0.56                                           Slipids
# 44       0.59   0.56   0.57                                            OpenFF
# 45       0.13   0.55   0.41            GROMOS-CKP, GROMOS NH3 charges and PME
# 46       0.78   0.55   0.63                                             OPLS4
# 47       0.21   0.55   0.44       GROMOS-CKP, Berger/Chiu NH3 charges and PME
# 48       0.59   0.55   0.56                                            OpenFF
# 49       0.15   0.55   0.41            GROMOS-CKP, GROMOS NH3 charges and PME
# 50       0.64   0.51   0.56                                          CHARMM36
# 51       0.66   0.50   0.55                                        ECC-lipids
# 52       0.04   0.44   0.30                Berger delivered by Peter Tieleman
# 53       0.27   0.43   0.37                                       CHARMM36-UA
# 54       0.32   0.41   0.38                                       CHARMM36-UA
# 55       0.06   0.41   0.29                                            Orange
# 56       0.02   0.40   0.27  Berger and Modified Höltje model for cholesterol
# 57       0.06   0.40   0.29                                      Charmm-Drude
# 58       0.54   0.40   0.44                                          CHARMM36
# 59       0.20   0.39   0.33       GROMOS-CKP, Berger/Chiu NH3 charges and PME
# 60       0.65   0.38   0.47                                        ECC-lipids
# 61       0.39   0.31   0.34                                            MacRog
# 62       0.68   0.29   0.42                                          CHARMM36
# 63       0.12   0.29   0.23                                           Slipids
# 64       0.67   0.29   0.42                                          CHARMM36
# 65       0.69   0.29   0.42                                          CHARMM36
# 66       0.67   0.27   0.40                                          CHARMM36
# 67       0.64   0.27   0.39                                          CHARMM36
# 68       0.57   0.27   0.37                                          CHARMM36
# 69       0.15   0.26   0.22                                       Chiu Gromos
# 70       0.58   0.26   0.37                        Lipid14 with Verlet scheme
# 71       0.09   0.24   0.19                                           Lipid17
# 72       0.11   0.21   0.18                                           Slipids
# 73       0.18   0.20   0.21                                           slipids
# 74       0.07   0.19   0.15                                        GROMOS-CKP
# 75       0.14   0.19   0.17                             Lipid17 and ff99 ions
# 76       0.63   0.18   0.33                                          Charmm36
# 77       0.14   0.17   0.16                                           Slipids
# 78       0.00   0.17   0.34                                          Charmm36
# 79       0.21   0.17   0.18                                            AMOEBA
# 80       0.37   0.15   0.23                                          Charmm36
# 81       0.60   0.14   0.29                                          Charmm36
# 82       0.63   0.13   0.30                                          Charmm36
# 83       0.26   0.12   0.17                                       CHARMM36-UA
# 84       0.66   0.12   0.30                                          CHARMM36
# 85       0.53   0.11   0.25                                          CHARMM36
# 86       0.02   0.09   0.08  Berger and Modified Höltje model for cholesterol
# 87       0.22   0.09   0.13                                       CHARMM36-UA
# 88       0.19   0.07   0.11                                            MacRog
# 89       0.04   0.07   0.06  Berger and Modified Höltje model for cholesterol
# 90       0.17   0.07   0.10                                            MacRog
# 91       0.26   0.07   0.13                                          CHARMM36
# 92       0.18   0.04   0.08                                          CHARMM36
# 93       0.11   0.03   0.05                                            Berger
# 94       0.13   0.03   0.06                                            Berger
# 95       0.01   0.02   0.02  Berger and Modified Höltje model for cholesterol
# 96       0.08   0.02   0.04                             Lipid17 and Dang ions
#
#         Molecules Number of molecules  Temperature   ID  FFQuality
# 0        POPC:SOL          (200:4000)       300.00  803        NaN
# 1        POPC:SOL          (200:4000)       300.00  815        NaN
# 2        POPC:SOL          (200:2400)       300.00  804        NaN
# 3        POPC:SOL          (200:8859)       300.00  805       0.15
# 4        POPC:SOL          (200:9000)       300.00  814       0.15
# 5        POPC:SOL          (200:1500)       300.00  802        NaN
# 6        POPC:SOL          (200:1000)       300.00  796        NaN
# 7        POPE:SOL         (500:25000)       310.00  414       0.10
# 8        POPC:SOL          (128:6400)       298.00  830       0.76
# 9        POPC:SOL         (256:10342)       300.00  115       0.94
# 10       POPC:SOL          (128:7290)       298.00  497       1.04
# 11       POPC:SOL           (64:3200)       298.15  715       0.14
# 12       POPC:SOL         (512:23943)       298.00  617       0.46
# 13       POPC:SOL        (1024:51200)       298.15  684       0.24
# 14       POPC:SOL          (200:1000)       300.00  817        NaN
# 15       POPC:SOL         (256:12800)       298.15  657       0.24
# 16       POPE:SOL         (336:13460)       310.00   29        NaN
# 17       POPE:SOL         (336:13460)       310.00   74        NaN
# 18       POPC:SOL        (1024:51200)       298.15  658       0.65
# 19       POPC:SOL           (64:3200)       298.15  674       0.55
# 20       POPE:SOL           (72:2304)       308.00  747       0.30
# 21       POPC:SOL          (200:2400)       300.00  798        NaN
# 22       POPC:SOL          (128:5120)       300.00  457       0.55
# 23       POPC:SOL        (1024:51200)       298.15  696       0.46
# 24   POPS:SOL:SOD        (72:3600:72)       298.00  443       0.40
# 25       POPC:SOL         (256:12800)       298.15  675       0.55
# 26       POPC:SOL          (288:5760)       298.00  606        NaN
# 27       POPE:SOL         (500:25000)       310.00  400       0.40
# 28       DMPC:SOL          (200:2000)       314.00  809        NaN
# 29       POPE:SOL           (72:2304)       308.00  750       0.20
# 30       DMPC:SOL          (200:1000)       314.00  800        NaN
# 31       POPC:SOL          (200:1500)       300.00  806        NaN
# 32       POPC:SOL          (128:6400)       298.00  831       0.95
# 33       POPC:SOL         (256:12800)       298.15  708       0.56
# 34       DOPC:SOL        (1024:51200)       303.15   47       0.92
# 35       DMPC:SOL          (200:9000)       314.00  813        NaN
# 36       DMPC:SOL          (200:1000)       314.00  811        NaN
# 37       POPC:SOL         (288:14400)       298.00   63       0.55
# 38  POPC:CHOL:SOL        (120:8:7290)       298.00  305       0.75
# 39       DOPC:SOL           (72:2880)       303.00  742        NaN
# 40       POPE:SOL           (72:2304)       308.00  751       0.00
# 41       POPC:SOL          (128:5120)       300.00  797       1.05
# 42       DOPC:SOL         (256:12800)       303.15  551       0.92
# 43       POPC:SOL           (64:3200)       298.15  664       0.76
# 44       POPC:SOL          (128:5000)       300.00  761       1.75
# 45   POPS:SOL:SOD      (128:4480:128)       298.00  473       0.60
# 46       DMPC:SOL          (200:2000)       314.00  810        NaN
# 47   POPS:SOL:SOD      (128:4480:128)       298.00  597       0.80
# 48       POPC:SOL          (128:5000)       300.00  792       2.06
# 49   POPS:SOL:SOD      (128:4480:128)       298.00  425       0.80
# 50       DOPC:SOL           (64:3200)       303.15  316       1.02
# 51       POPC:SOL          (128:6400)       300.00  573       0.56
# 52       POPC:SOL           (128:896)       298.00  128        NaN
# 53       POPE:SOL         (336:15254)       310.00  233       0.30
# 54       POPE:SOL         (336:15254)       310.00  352       0.30
# 55       POPC:SOL           (72:2880)       298.00   38       0.26
# 56  POPC:CHOL:SOL       (110:18:8481)       298.00  589       0.27
# 57       POPE:SOL          (144:5040)       310.00  731       0.80
# 58       SOL:POPE          (5760:144)       310.00  430       1.30
# 59   POPS:SOL:SOD      (128:4480:128)       298.00  535       0.70
# 60       POPC:SOL          (128:6400)       300.00   43       0.76
# 61       POPC:SOL          (288:1440)       298.00  378        NaN
# 62       POPC:SOL          (256:9767)       300.00  558       1.25
# 63   POPG:SOL:SOD     (288:10664:288)       298.00  207        NaN
# 64       POPC:SOL          (200:8880)       300.00  164       1.25
# 65       POPC:SOL        (1024:51200)       298.15  701       1.25
# 66       POPC:SOL         (256:12800)       298.15  710       1.25
# 67       POPC:SOL           (64:3200)       298.15  678       1.46
# 68       POPC:SOL           (64:3200)       298.15  546       1.55
# 69       POPC:SOL          (128:3552)       298.00  422       0.76
# 70       POPC:SOL          (128:5120)       298.15   30       0.85
# 71       POPE:SOL         (500:25000)       310.00  195       1.60
# 72   POPS:SOL:SOD      (128:4480:128)       298.00  529       0.30
# 73  CHOL:POPC:SOL     (256:256:20334)       298.00   82       3.39
# 74       POPC:SOL         (500:25000)       298.00  202       1.35
# 75   POPS:SOL:SOD        (72:3600:72)       298.00  521       0.80
# 76       POPC:SOL          (200:1000)       300.00  795        NaN
# 77   POPS:SOL:SOD      (128:4480:128)       298.00  338       0.40
# 78       SM16:SOL          (200:9000)       328.15  765       2.00
# 79       POPE:SOL           (72:2880)       310.00  730       3.80
# 80       POPE:SOL          (144:5760)       310.00  790       2.00
# 81       DMPC:SOL           (64:3200)       313.15  788        NaN
# 82       DMPC:SOL           (64:3200)       313.15  789        NaN
# 83   POPS:SOL:SOD      (128:4480:128)       298.00  263       0.80
# 84       DMPC:SOL         (200:10000)       314.00  808        NaN
# 85       SOL:POPE         (25000:500)       310.00   67       1.70
# 86  POPC:CHOL:SOL       (64:64:10314)       298.00  299       1.29
# 87   POPS:SOL:SOD      (128:4480:128)       298.00  367       1.20
# 88   POPS:SOL:SOD      (128:4480:128)       298.00  292       1.80
# 89  POPC:CHOL:SOL        (84:44:6794)       298.00  206       0.33
# 90   POPS:SOL:SOD      (128:4480:128)       298.00   26       1.60
# 91   POPS:SOL:SOD      (128:4480:128)       298.00    5       1.70
# 92   POPS:SOL:SOD      (128:4480:128)       298.00  106       2.20
# 93   POPS:SOL:SOD      (128:4480:128)       298.00  480       2.30
# 94   POPS:SOL:SOD      (128:4480:128)       298.00  502       2.40
# 95  POPC:CHOL:SOL        (50:78:5782)       298.00   15        NaN
# 96   POPS:SOL:SOD        (72:3600:72)       298.00  483       2.10
# Sorted based on  headgroup  quality
# **FAILURE:** no FF defined for the system
# 'a7f/9f3/a7f9f36feaa77791483dadb0157f86a6a519f2c3/a30f01e8771c44dc59b78753d1dd27ca67920e38/'
# **FAILURE:** no FF defined for the system
# 'c04/cdb/c04cdb61143bb72ba2ddee11599e6bbfaf6cb211/a31f42800216d84d2242eae2af8ac2cbd6b033ee/'
#      headgroup  tails  total  \
# 0         0.78   0.55   0.63
# 1         0.75   0.78   0.77
# 2         0.73   0.84   0.81
# 3         0.73   0.84   0.80
# 4         0.71   0.80   0.77
# 5         0.70   0.87   0.81
# 6         0.70   0.87   0.81
# 7         0.70   0.85   0.80
# 8         0.69   0.59   0.62
# 9         0.69   0.64   0.66
# 10        0.69   0.63   0.65
# 11        0.69   0.29   0.42
# 12        0.68   0.72   0.71
# 13        0.68   0.29   0.42
# 14        0.67   0.71   0.70
# 15        0.67   0.29   0.42
# 16        0.67   0.27   0.40
# 17        0.66   0.74   0.72
# 18        0.66   0.63   0.64
# 19        0.66   0.60   0.62
# 20        0.66   0.50   0.55
# 21        0.66   0.12   0.30
# 22        0.66   0.66   0.66
# 23        0.65   0.38   0.47
# 24        0.65   0.65   0.65
# 25        0.64   0.51   0.56
# 26        0.64   0.61   0.62
# 27        0.64   0.57   0.59
# 28        0.64   0.27   0.39
# 29        0.63   0.13   0.30
# 30        0.63   0.69   0.67
# 31        0.63   0.18   0.33
# 32        0.63   0.57   0.59
# 33        0.62   0.69   0.67
# 34        0.62   0.59   0.60
# 35        0.62   0.73   0.69
# 36        0.61   0.66   0.64
# 37        0.60   0.70   0.66
# 38        0.60   0.57   0.58
# 39        0.60   0.14   0.29
# 40        0.59   0.55   0.56
# 41        0.59   0.67   0.64
# 42        0.59   0.56   0.57
# 43        0.58   0.26   0.37
# 44        0.57   0.72   0.67
# 45        0.57   0.27   0.37
# 46        0.56   0.62   0.60
# 47        0.56   0.72   0.67
# 48        0.55   0.56   0.56
# 49        0.54   0.40   0.44
# 50        0.53   0.11   0.25
# 51        0.49   0.73   0.65
# 52        0.39   0.31   0.34
# 53        0.37   0.15   0.23
# 54        0.32   0.41   0.38
# 55        0.30   0.69   0.56
# 56        0.30   0.65   0.53
# 57        0.29   0.65   0.53
# 58        0.28   0.57   0.48
# 59        0.27   0.43   0.37
# 60        0.26   0.12   0.17
# 61        0.26   0.07   0.13
# 62        0.22   0.09   0.13
# 63        0.21   0.55   0.44
# 64        0.21   0.17   0.18
# 65        0.20   0.39   0.33
# 66        0.19   0.07   0.11
# 67        0.18   0.04   0.08
# 68        0.18   0.20   0.21
# 69        0.17   0.07   0.10
# 70        0.16   0.66   0.50
# 71        0.15   0.55   0.41
# 72        0.15   0.26   0.22
# 73        0.14   0.17   0.16
# 74        0.14   0.19   0.17
# 75        0.13   0.03   0.06
# 76        0.13   0.55   0.41
# 77        0.12   0.29   0.23
# 78        0.11   0.21   0.18
# 79        0.11   0.03   0.05
# 80        0.10   0.72   0.51
# 81        0.10   0.71   0.51
# 82        0.09   0.24   0.19
# 83        0.08   0.02   0.04
# 84        0.07   0.19   0.15
# 85        0.06   0.40   0.29
# 86        0.06   0.41   0.29
# 87        0.04   0.07   0.06
# 88        0.04   0.44   0.30
# 89        0.03   0.73   0.50
# 90        0.02   0.58   0.39
# 91        0.02   0.40   0.27
# 92        0.02   0.09   0.08
# 93        0.01   0.02   0.02
# 94        0.01   0.73   0.49
# 95        0.01   0.78   0.52
# 96        0.00   0.00   0.00
# 97        0.00   0.00   0.00
# 98        0.00   0.00   0.00
# 99        0.00   0.00   0.00
# 100       0.00   0.00   0.00
# 101       0.00   0.00   0.00
# 102       0.00   0.00   0.00
#
#                                            Forcefield          Molecules  \
# 0                                               OPLS4           DMPC:SOL
# 1                                              OPLS3e           POPC:SOL
# 2                                              OPLS3e           POPC:SOL
# 3                                               OPLS4           POPC:SOL
# 4                                               OPLS4           POPC:SOL
# 5                                               OPLS4           POPC:SOL
# 6                                              OPLS3e           POPC:SOL
# 7                                               OPLS4           POPC:SOL
# 8                                               OPLS4           DMPC:SOL
# 9                                            CHARMM36           DMPC:SOL
# 10                                           CHARMM36           POPC:SOL
# 11                                           CHARMM36           POPC:SOL
# 12                                              OPLS4           POPC:SOL
# 13                                           CHARMM36           POPC:SOL
# 14                                             MacRog           POPC:SOL
# 15                                           CHARMM36           POPC:SOL
# 16                                           CHARMM36           POPC:SOL
# 17                                 C36_Slipids_Hybrid           POPC:SOL
# 18                                 C36_Slipids_Hybrid           POPC:SOL
# 19                                              OPLS4           DMPC:SOL
# 20                                         ECC-lipids           POPC:SOL
# 21                                           CHARMM36           DMPC:SOL
# 22                                             MacRog           POPC:SOL
# 23                                         ECC-lipids           POPC:SOL
# 24                                           CHARMM36           DMPC:SOL
# 25                                           CHARMM36           DOPC:SOL
# 26                                           CHARMM36           DOPC:SOL
# 27                                           CHARMM36           DOPC:SOL
# 28                                           CHARMM36           POPC:SOL
# 29                                           Charmm36           DMPC:SOL
# 30                                             MacRog           POPC:SOL
# 31                                           Charmm36           POPC:SOL
# 32                                             OpenFF           POPC:SOL
# 33                                           CHARMM36           POPC:SOL
# 34                                             MacRog           POPC:SOL
# 35                                            Slipids           POPC:SOL
# 36                                             MacRog           POPC:SOL
# 37                                             MacRog           POPC:SOL
# 38                                             AMOEBA           DOPC:SOL
# 39                                           Charmm36           DMPC:SOL
# 40                                             OpenFF           POPC:SOL
# 41                                            Slipids           POPC:SOL
# 42                                             OpenFF           POPC:SOL
# 43                         Lipid14 with Verlet scheme           POPC:SOL
# 44                                            Lipid17           POPC:SOL
# 45                                           CHARMM36           POPC:SOL
# 46                                            Slipids           POPC:SOL
# 47                                            Lipid17           POPC:SOL
# 48                                            Slipids           POPC:SOL
# 49                                           CHARMM36           SOL:POPE
# 50                                           CHARMM36           SOL:POPE
# 51                                            Lipid17           POPC:SOL
# 52                                             MacRog           POPC:SOL
# 53                                           Charmm36           POPE:SOL
# 54                                        CHARMM36-UA           POPE:SOL
# 55                       Charmm-Drude polarizable2023           POPE:SOL
# 56                       Charmm-Drude polarizable2023           POPE:SOL
# 57                                         GROMOS-CKP           POPE:SOL
# 58                       Charmm-Drude polarizable2023           POPE:SOL
# 59                                        CHARMM36-UA           POPE:SOL
# 60                                        CHARMM36-UA       POPS:SOL:SOD
# 61                                           CHARMM36       POPS:SOL:SOD
# 62                                        CHARMM36-UA       POPS:SOL:SOD
# 63        GROMOS-CKP, Berger/Chiu NH3 charges and PME       POPS:SOL:SOD
# 64                                             AMOEBA           POPE:SOL
# 65        GROMOS-CKP, Berger/Chiu NH3 charges and PME       POPS:SOL:SOD
# 66                                             MacRog       POPS:SOL:SOD
# 67                                           CHARMM36       POPS:SOL:SOD
# 68                                            slipids      CHOL:POPC:SOL
# 69                                             MacRog       POPS:SOL:SOD
# 70              ECC-lipids, SPC water model, ECC-ions       POPS:SOL:SOD
# 71             GROMOS-CKP, GROMOS NH3 charges and PME       POPS:SOL:SOD
# 72                                        Chiu Gromos           POPC:SOL
# 73                                            Slipids       POPS:SOL:SOD
# 74                              Lipid17 and ff99 ions       POPS:SOL:SOD
# 75                                             Berger       POPS:SOL:SOD
# 76             GROMOS-CKP, GROMOS NH3 charges and PME       POPS:SOL:SOD
# 77                                            Slipids       POPG:SOL:SOD
# 78                                            Slipids       POPS:SOL:SOD
# 79                                             Berger       POPS:SOL:SOD
# 80                                            Slipids           POPE:SOL
# 81                                            Slipids           POPE:SOL
# 82                                            Lipid17           POPE:SOL
# 83                              Lipid17 and Dang ions       POPS:SOL:SOD
# 84                                         GROMOS-CKP           POPC:SOL
# 85                                       Charmm-Drude           POPE:SOL
# 86                                             Orange           POPC:SOL
# 87   Berger and Modified Höltje model for cholesterol      POPC:CHOL:SOL
# 88                 Berger delivered by Peter Tieleman           POPC:SOL
# 89                                             Berger           POPC:SOL
# 90   Berger and Modified Höltje model for cholesterol      POPC:CHOL:SOL
# 91   Berger and Modified Höltje model for cholesterol      POPC:CHOL:SOL
# 92   Berger and Modified Höltje model for cholesterol      POPC:CHOL:SOL
# 93   Berger and Modified Höltje model for cholesterol      POPC:CHOL:SOL
# 94                                             Berger           POPC:SOL
# 95                                            Slipids           POPE:SOL
# 96                                            Lipid17  POPC:POPG:SOL:SOD
# 97                                           CHARMM36  POPG:POPC:SOL:SOD
# 98                                         lipid17ecc  POPG:POPC:SOL:SOD
# 99                                            Slipids  POPC:POPG:SOD:SOL
# 100                                        lipid17ecc  POPG:POPC:SOL:SOD
# 101                                          CHARMM36  POPG:POPC:SOL:SOD
# 102                                           lipid17  POPG:POPC:SOL:SOD
#
#       Number of molecules  Temperature   ID  FFQuality
# 0              (200:2000)       314.00  810        NaN
# 1              (200:1000)       300.00  796        NaN
# 2              (200:8859)       300.00  805       0.15
# 3              (200:9000)       300.00  814       0.15
# 4              (200:1500)       300.00  802        NaN
# 5              (200:4000)       300.00  803        NaN
# 6              (200:4000)       300.00  815        NaN
# 7              (200:2400)       300.00  804        NaN
# 8              (200:1000)       314.00  811        NaN
# 9              (200:1000)       314.00  800        NaN
# 10             (200:1500)       300.00  806        NaN
# 11           (1024:51200)       298.15  701       1.25
# 12             (200:1000)       300.00  817        NaN
# 13             (256:9767)       300.00  558       1.25
# 14           (1024:51200)       298.15  658       0.65
# 15             (200:8880)       300.00  164       1.25
# 16            (256:12800)       298.15  710       1.25
# 17             (128:6400)       298.00  830       0.76
# 18             (128:6400)       298.00  831       0.95
# 19             (200:9000)       314.00  813        NaN
# 20             (128:6400)       300.00  573       0.56
# 21            (200:10000)       314.00  808        NaN
# 22            (256:12800)       298.15  675       0.55
# 23             (128:6400)       300.00   43       0.76
# 24             (200:2000)       314.00  809        NaN
# 25              (64:3200)       303.15  316       1.02
# 26           (1024:51200)       303.15   47       0.92
# 27            (256:12800)       303.15  551       0.92
# 28              (64:3200)       298.15  678       1.46
# 29              (64:3200)       313.15  789        NaN
# 30             (128:5120)       300.00  457       0.55
# 31             (200:1000)       300.00  795        NaN
# 32             (128:5120)       300.00  797       1.05
# 33             (200:2400)       300.00  798        NaN
# 34            (288:14400)       298.00   63       0.55
# 35            (512:23943)       298.00  617       0.46
# 36             (288:5760)       298.00  606        NaN
# 37              (64:3200)       298.15  674       0.55
# 38              (72:2880)       303.00  742        NaN
# 39              (64:3200)       313.15  788        NaN
# 40             (128:5000)       300.00  792       2.06
# 41           (1024:51200)       298.15  696       0.46
# 42             (128:5000)       300.00  761       1.75
# 43             (128:5120)       298.15   30       0.85
# 44           (1024:51200)       298.15  684       0.24
# 45              (64:3200)       298.15  546       1.55
# 46            (256:12800)       298.15  708       0.56
# 47            (256:12800)       298.15  657       0.24
# 48              (64:3200)       298.15  664       0.76
# 49             (5760:144)       310.00  430       1.30
# 50            (25000:500)       310.00   67       1.70
# 51              (64:3200)       298.15  715       0.14
# 52             (288:1440)       298.00  378        NaN
# 53             (144:5760)       310.00  790       2.00
# 54            (336:15254)       310.00  352       0.30
# 55              (72:2304)       308.00  747       0.30
# 56              (72:2304)       308.00  750       0.20
# 57            (500:25000)       310.00  400       0.40
# 58              (72:2304)       308.00  751       0.00
# 59            (336:15254)       310.00  233       0.30
# 60         (128:4480:128)       298.00  263       0.80
# 61         (128:4480:128)       298.00    5       1.70
# 62         (128:4480:128)       298.00  367       1.20
# 63         (128:4480:128)       298.00  597       0.80
# 64              (72:2880)       310.00  730       3.80
# 65         (128:4480:128)       298.00  535       0.70
# ...
# 15        POPC:SOL          (128:5120)       303.00  591        NaN    NaN
# 16   POPC:SOL:CHOL    (1024:64000:256)       298.15  677        NaN    NaN
# 17   POPC:SOL:CHOL      (256:16000:64)       298.15  706        NaN    NaN
# 18        POPC:SOL         (256:12800)       298.15  657       0.56   0.72
# 19        POPC:SOL        (1024:51200)       298.15  684       0.57   0.72
# 20        POPC:SOL           (72:2880)       298.00   38       0.06   0.41
# 21   POPC:SOL:CHOL         (64:3600:8)       298.15  665        NaN    NaN
# 22   POPC:SOL:CHOL         (64:3600:8)       298.15  680        NaN    NaN
# 23   POPC:CHOL:SOL       (110:18:8481)       298.00  589       0.02   0.40
# 24        POPC:SOL          (128:6400)       313.00  127        NaN    NaN
# 25    POPS:SOL:SOD      (128:4480:128)       298.00  529       0.11   0.21
# 26        POPE:SOL         (336:15254)       310.00  352       0.32   0.41
# 27        POPE:SOL         (336:15254)       310.00  233       0.27   0.43
# 28        POPE:SOL           (72:2304)       308.00  747       0.30   0.69
# 29   POPC:CHOL:SOL        (84:44:6794)       298.00  206       0.04   0.07
# 30   POPC:SOL:CHOL      (256:14400:32)       298.15  695        NaN    NaN
# 31   POPC:SOL:CHOL    (1024:57600:128)       298.15  660        NaN    NaN
# 32    POPS:SOL:SOD      (128:4480:128)       298.00  338       0.14   0.17
# 33    POPS:SOL:SOD        (72:3600:72)       298.00  443       0.16   0.66
# 34        POPE:SOL         (500:25000)       310.00  400       0.29   0.65
# 35        DOPC:SOL        (1024:51200)       293.15   76        NaN    NaN
# 36        POPC:SOL           (72:2239)       303.00  748        NaN    NaN
# 37   POPC:SOL:CHOL      (256:14400:32)       298.15  681        NaN    NaN
# 38   POPC:SOL:CHOL    (1024:57600:128)       298.15  697        NaN    NaN
# 39        POPC:SOL         (512:23943)       298.00  617       0.62   0.73
# 40        POPC:SOL        (1024:51200)       298.15  696       0.59   0.67
# 41   POPC:SOL:CHOL    (1024:57600:128)       298.15  663        NaN    NaN
# 42   POPC:SOL:CHOL      (256:14400:32)       298.15  689        NaN    NaN
# 43        POPC:SOL          (128:6400)       313.00  595        NaN    NaN
# 44        DPPC:SOL          (128:5841)       323.00  267        NaN    NaN
# 45        DOPC:SOL           (64:3200)       293.15  520        NaN    NaN
# 46        DOPC:SOL         (256:12800)       293.15  532        NaN    NaN
# 47   POPC:SOL:CHOL         (64:3600:8)       298.15  672        NaN    NaN
# 48        POPC:SOL         (256:12800)       298.15  675       0.66   0.66
# 49        POPC:SOL          (128:5120)       300.00  457       0.63   0.69
# 50        POPC:SOL         (288:14400)       298.00   63       0.62   0.59
# 51        POPC:SOL           (64:3200)       298.15  674       0.60   0.70
# 52        POPC:SOL         (256:12800)       298.15  708       0.56   0.62
# 53        POPC:SOL          (128:6400)       300.00  573       0.66   0.50
# 54        POPC:SOL          (128:6400)       313.00  405        NaN    NaN
# 55        POPC:SOL           (72:2234)       313.00  584        NaN    NaN
# 56        POPC:SOL          (128:6400)       313.00  204        NaN    NaN
# 57    POPS:SOL:SOD      (128:4480:128)       298.00  473       0.13   0.55
# 58   POPC:SOL:CHOL        (64:4000:16)       298.15  702        NaN    NaN
# 59        POPC:SOL        (1024:51200)       298.15  658       0.67   0.71
# 60    POPS:SOL:SOD      (128:4480:128)       298.00  535       0.20   0.39
# 61        DPPC:SOL          (128:5841)       323.00  545        NaN    NaN
# 62   POPC:SOL:CHOL    (1024:64000:256)       298.15  691        NaN    NaN
# 63   POPC:SOL:CHOL      (256:16000:64)       298.15  687        NaN    NaN
# 64   POPC:CHOL:SOL        (120:8:7290)       298.00  305       0.02   0.58
# 65        POPC:SOL           (64:3200)       298.15  664       0.55   0.56
# 66        POPC:SOL          (128:6400)       300.00   43       0.65   0.38
# 67        POPC:SOL          (128:3552)       298.00  422       0.15   0.26
# 68        POPC:SOL          (128:6400)       298.00  830       0.66   0.74
# 69        DPPC:SOL          (288:8928)       323.00  728        NaN    NaN
# 70        POPE:SOL          (144:5040)       310.00  731       0.06   0.40
# 71    POPS:SOL:SOD        (72:3600:72)       298.00  521       0.14   0.19
# 72    POPS:SOL:SOD      (128:4480:128)       298.00  263       0.26   0.12
# 73    POPS:SOL:SOD      (128:4480:128)       298.00  597       0.21   0.55
# 74    POPS:SOL:SOD      (128:4480:128)       298.00  425       0.15   0.55
# 75        DMPC:SOL          (128:3655)       323.00  147        NaN    NaN
# 76        POPC:SOL           (72:2239)       303.00  752        NaN    NaN
# 77        POPC:SOL           (72:2239)       303.00  749        NaN    NaN
# 78        POPC:SOL          (128:5120)       298.15   30       0.58   0.26
# 79        POPC:SOL         (256:10342)       303.00  151        NaN    NaN
# 80        DOPC:SOL         (256:12800)       303.15  551       0.64   0.57
# 81        POPC:SOL          (126:3948)       303.00  602        NaN    NaN
# 82        DOPC:SOL        (1024:51200)       303.15   47       0.64   0.61
# 83        POPC:SOL          (128:6400)       303.00  734        NaN    NaN
# 84   POPC:SOL:CHOL        (64:4000:16)       298.15  692        NaN    NaN
# 85        POPC:SOL         (256:10342)       300.00  115       0.01   0.73
# 86        POPC:SOL          (128:6400)       298.00  831       0.66   0.63
# 87        POPC:SOL          (128:4040)       303.00  281        NaN    NaN
# 88        POPC:SOL          (128:4040)       303.00  224        NaN    NaN
# 89        DOPC:SOL           (64:3200)       303.15  316       0.64   0.51
# 90        POPC:SOL          (128:5120)       303.00  462        NaN    NaN
# 91        POPC:SOL          (128:4040)       303.00  310        NaN    NaN
# 92        POPC:SOL          (128:5120)       303.00  361        NaN    NaN
# 93        POPC:SOL          (128:5120)       303.00   98        NaN    NaN
# 94        POPC:SOL          (128:5120)       303.00  554        NaN    NaN
# 95        POPC:SOL          (128:5120)       303.00   99        NaN    NaN
# 96        POPC:SOL          (128:7290)       298.00  497       0.03   0.73
# 97        POPC:SOL          (128:5120)       300.00  797       0.63   0.57
# 98        POPC:SOL          (122:4880)       303.00  433        NaN    NaN
# 99        POPC:SOL          (128:4040)       303.00  541        NaN    NaN
# 100       POPC:SOL          (128:5120)       303.00  428        NaN    NaN
# 101       POPC:SOL          (128:5120)       303.00  123        NaN    NaN
# 102       POPC:SOL          (128:5120)       303.00  301        NaN    NaN
# 103       POPC:SOL          (128:5120)       303.00   70        NaN    NaN
# 104       POPC:SOL          (200:9000)       303.00   90        NaN    NaN
# 105  POPC:CHOL:SOL      (256:32:14400)       298.15  119        NaN    NaN
# 106  POPC:CHOL:SOL    (1024:128:57600)       298.15  426        NaN    NaN
# 107       DOPC:SOL         (256:12800)       313.15  598        NaN    NaN
# 108       DOPC:SOL        (1024:51200)       313.15  504        NaN    NaN
# 109       DPPC:SOL          (128:3840)       323.00  463        NaN    NaN
# 110   POPS:SOL:SOD      (128:4480:128)       298.00  367       0.22   0.09
# 111       POPC:SOL           (72:2239)       303.00  144        NaN    NaN
# 112       POPC:SOL          (128:5120)       303.15  563        NaN    NaN
# 113  POPC:CHOL:SOL         (64:8:3600)       298.15  109        NaN    NaN
# 114       POPC:SOL        (1024:51200)       298.15  701       0.69   0.29
# 115       POPC:SOL          (256:9767)       300.00  558       0.68   0.29
# 116       POPC:SOL          (200:8880)       300.00  164       0.67   0.29
# 117       POPC:SOL         (256:12800)       298.15  710       0.67   0.27
# 118       POPC:SOL          (200:9000)       313.00  512        NaN    NaN
# 119       DOPC:SOL           (64:3200)       313.15  396        NaN    NaN
# 120  POPC:CHOL:SOL       (64:64:10314)       298.00  299       0.02   0.09
# 121       SOL:POPE          (5760:144)       310.00  430       0.54   0.40
# 122       POPC:SOL          (128:5120)       303.00  612        NaN    NaN
# 123       DOPC:SOL         (256:12800)       323.15  325        NaN    NaN
# 124       DOPC:SOL        (1024:51200)       323.15  104        NaN    NaN
# 125       POPC:SOL         (500:25000)       298.00  202       0.07   0.19
# 126  POPC:CHOL:SOL    (1024:256:64000)       298.15   88        NaN    NaN
# 127       SOPC:SOL           (64:3200)       303.15  820        NaN    NaN
# 128       DOPC:SOL           (64:3200)       323.15  547        NaN    NaN
# 129       POPC:SOL           (64:3200)       298.15  678       0.64   0.27
# 130       DPPC:SOL         (512:20480)       325.00   87        NaN    NaN
# 131       DPPC:SOL           (72:2880)       323.00   41        NaN    NaN
# 132       DMPC:SOL          (128:5097)       323.00  501        NaN    NaN
# 133  POPC:CHOL:SOL        (64:16:4000)       298.15  525        NaN    NaN
# 134  POPC:CHOL:SOL      (256:64:16000)       298.15   72        NaN    NaN
# 135  POPC:SOL:CHOL     (256:20800:160)       298.15  694        NaN    NaN
# 136  POPC:SOL:CHOL    (1024:83200:640)       298.15  673        NaN    NaN
# 137       POPC:SOL           (64:3200)       298.15  546       0.57   0.27
# 138   POPS:SOL:SOD      (128:4480:128)       298.00   26       0.17   0.07
# 139       POPE:SOL         (500:25000)       310.00  195       0.09   0.24
# 140       POPC:SOL           (72:2242)       303.00  533        NaN    NaN
# 141  POPC:SOL:CHOL     (256:20800:160)       298.15  668        NaN    NaN
# 142  POPC:SOL:CHOL    (1024:83200:640)       298.15  670        NaN    NaN
# 143       DPPC:SOL           (72:2880)       325.00  171        NaN    NaN
# 144       DPPC:SOL           (72:2188)       325.00  199        NaN    NaN
# 145       DPPC:SOL           (72:2189)       323.00  319        NaN    NaN
# 146       DPPC:SOL           (72:2197)       323.00  390        NaN    NaN
# 147   POPS:SOL:SOD      (128:4480:128)       298.00    5       0.26   0.07
# 148       SOL:POPE         (25000:500)       310.00   67       0.53   0.11
# 149  POPC:SOL:CHOL        (64:5200:40)       298.15  661        NaN    NaN
# 150  POPC:SOL:CHOL        (64:5200:40)       298.15  688        NaN    NaN
# 151  POPC:SOL:CHOL        (64:6000:56)       298.15  703        NaN    NaN
# 152  POPC:SOL:CHOL     (256:24000:224)       298.15  712        NaN    NaN
# 153  POPC:SOL:CHOL    (1024:96000:896)       298.15  682        NaN    NaN
# 154       POPC:SOL          (128:5000)       300.00  761       0.59   0.56
# 155       DPPC:SOL           (72:2880)       325.00  438        NaN    NaN
# 156   POPS:SOL:SOD      (128:4480:128)       298.00  292       0.19   0.07
# 157       DMPC:SOL        (1024:51200)       333.15  356        NaN    NaN
# 158       SM16:SOL          (200:9000)       328.15  765       0.00   0.17
# 159       POPE:SOL          (144:5760)       310.00  790       0.37   0.15
# 160  POPC:SOL:CHOL     (256:20800:160)       298.15  679        NaN    NaN
# 161  POPC:SOL:CHOL        (64:5200:40)       298.15  716        NaN    NaN
# 162  POPC:SOL:CHOL    (1024:83200:640)       298.15  698        NaN    NaN
# 163  POPC:SOL:CHOL        (64:6000:56)       298.15  704        NaN    NaN
# 164  POPC:SOL:CHOL     (256:24000:224)       298.15  699        NaN    NaN
# 165  POPC:SOL:CHOL    (1024:96000:896)       298.15  671        NaN    NaN
# 166       POPC:SOL          (128:5000)       300.00  792       0.59   0.55
# 167       DMPC:SOL         (256:12800)       333.15   42        NaN    NaN
# 168       DMPC:SOL           (64:3200)       333.15  510        NaN    NaN
# 169   POPS:SOL:SOD        (72:3600:72)       298.00  483       0.08   0.02
# 170  POPC:CHOL:SOL    (1024:640:83200)       298.15  550        NaN    NaN
# 171       DPPC:SOL        (1024:51200)       333.15  254        NaN    NaN
# 172       DPPC:SOL         (256:12800)       333.15  309        NaN    NaN
# 173   POPS:SOL:SOD      (128:4480:128)       298.00  106       0.18   0.04
# 174       DPPC:SOL           (72:2880)       323.00  472        NaN    NaN
# 175  POPC:CHOL:SOL     (256:160:20800)       298.15  275        NaN    NaN
# 176  POPC:CHOL:SOL        (64:40:5200)       298.15  620        NaN    NaN
# 177  POPC:CHOL:SOL     (256:224:24000)       298.15  166        NaN    NaN
# 178  POPC:CHOL:SOL    (1024:896:96000)       298.15  543        NaN    NaN
# 179  POPC:SOL:CHOL    (1024:96000:896)       298.15  717        NaN    NaN
# 180  POPC:CHOL:SOL        (64:56:6000)       298.15   91        NaN    NaN
# 181       DPPC:SOL           (64:3200)       333.15   27        NaN    NaN
# 182   POPS:SOL:SOD      (128:4480:128)       298.00  480       0.11   0.03
# 183  POPC:SOL:CHOL     (256:24000:224)       298.15  714        NaN    NaN
# 184  POPC:SOL:CHOL        (64:6000:56)       298.15  707        NaN    NaN
# 185   POPS:SOL:SOD      (128:4480:128)       298.00  502       0.13   0.03
# 186  CHOL:POPC:SOL     (256:256:20334)       298.00   82       0.18   0.20
# 187       POPE:SOL           (72:2880)       310.00  730       0.21   0.17
#
#      total
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN
# 6     0.52
# 7      NaN
# 8     0.65
# 9     0.80
# 10    0.81
# 11     NaN
# 12     NaN
# 13     NaN
# 14    0.53
# 15     NaN
# 16     NaN
# 17     NaN
# 18    0.67
# 19    0.67
# 20    0.29
# 21     NaN
# 22     NaN
# 23    0.27
# 24     NaN
# 25    0.18
# 26    0.38
# 27    0.37
# 28    0.56
# 29    0.06
# 30     NaN
# 31     NaN
# 32    0.16
# 33    0.50
# 34    0.53
# 35     NaN
# 36     NaN
# 37     NaN
# 38     NaN
# 39    0.69
# 40    0.64
# 41     NaN
# 42     NaN
# 43     NaN
# 44     NaN
# 45     NaN
# 46     NaN
# 47     NaN
# 48    0.66
# 49    0.67
# 50    0.60
# 51    0.66
# 52    0.60
# 53    0.55
# 54     NaN
# 55     NaN
# 56     NaN
# 57    0.41
# 58     NaN
# 59    0.70
# 60    0.33
# 61     NaN
# 62     NaN
# 63     NaN
# 64    0.39
# 65    0.56
# 66    0.47
# 67    0.22
# 68    0.72
# 69     NaN
# 70    0.29
# 71    0.17
# 72    0.17
# 73    0.44
# 74    0.41
# 75     NaN
# 76     NaN
# 77     NaN
# 78    0.37
# 79     NaN
# 80    0.59
# 81     NaN
# 82    0.62
# 83     NaN
# 84     NaN
# 85    0.49
# 86    0.64
# 87     NaN
# 88     NaN
# 89    0.56
# 90     NaN
# 91     NaN
# 92     NaN
# 93     NaN
# 94     NaN
# 95     NaN
# 96    0.50
# 97    0.59
# 98     NaN
# 99     NaN
# 100    NaN
# 101    NaN
# 102    NaN
# 103    NaN
# 104    NaN
# 105    NaN
# 106    NaN
# 107    NaN
# 108    NaN
# 109    NaN
# 110   0.13
# 111    NaN
# 112    NaN
# 113    NaN
# 114   0.42
# 115   0.42
# 116   0.42
# 117   0.40
# 118    NaN
# 119    NaN
# 120   0.08
# 121   0.44
# 122    NaN
# 123    NaN
# 124    NaN
# 125   0.15
# 126    NaN
# 127    NaN
# 128    NaN
# 129   0.39
# 130    NaN
# 131    NaN
# 132    NaN
# 133    NaN
# 134    NaN
# 135    NaN
# 136    NaN
# 137   0.37
# 138   0.10
# 139   0.19
# 140    NaN
# 141    NaN
# 142    NaN
# 143    NaN
# 144    NaN
# 145    NaN
# 146    NaN
# 147   0.13
# 148   0.25
# 149    NaN
# 150    NaN
# 151    NaN
# 152    NaN
# 153    NaN
# 154   0.57
# 155    NaN
# 156   0.11
# 157    NaN
# 158   0.34
# 159   0.23
# 160    NaN
# 161    NaN
# 162    NaN
# 163    NaN
# 164    NaN
# 165    NaN
# 166   0.56
# 167    NaN
# 168    NaN
# 169   0.04
# 170    NaN
# 171    NaN
# 172    NaN
# 173   0.08
# 174    NaN
# 175    NaN
# 176    NaN
# 177    NaN
# 178    NaN
# 179    NaN
# 180    NaN
# 181    NaN
# 182   0.05
# 183    NaN
# 184    NaN
# 185   0.06
# 186   0.21
# 187   0.18

# %% [markdown]
# # Show ranking separately for each lipid based on total, sn-1, sn-2, or headgroup quality

# %%
Fragments = ['total','sn-1','sn-2','headgroup']

for SortBasedOn in Fragments:
    for lipid in lipids_set:
        print('Quality of',SortBasedOn,' of ',lipid)
        FFrankingPath = os.path.join(
            NMLDB_ROOT_PATH,
            'Data', 'Ranking',
            f'{lipid}_{SortBasedOn}_Ranking.json')
    
        try:
            with open(FFrankingPath) as json_file:
                FFranking = json.load(json_file)
        except:
            print('File not found')
            continue
            
        showTable(FFranking, lipid)
# Out:
# Quality of total  of  Lipid(DRPC)
# File not found
# Quality of total  of  Lipid(DOPE)
# File not found
# Quality of total  of  Lipid(SM16)
# File not found
# Quality of total  of  Lipid(SLiPC)
# File not found
# Quality of total  of  Lipid(SDPE)
# File not found
# Quality of total  of  Lipid(SDG)
# File not found
# Quality of total  of  Lipid(DMPC)
# File not found
# Quality of total  of  Lipid(GB3)
# File not found
# Quality of total  of  Lipid(PAzePCdeprot)
# File not found
# Quality of total  of  Lipid(POPG)
# File not found
# Quality of total  of  Lipid(SAPI25)
# File not found
# Quality of total  of  Lipid(DOPS)
# File not found
# Quality of total  of  Lipid(SM18)
# File not found
# Quality of total  of  Lipid(DLIPC)
# File not found
# Quality of total  of  Lipid(DPPG)
# File not found
# Quality of total  of  Lipid(DDOPC)
# File not found
# Quality of total  of  Lipid(POPE)
# File not found
# Quality of total  of  Lipid(DPPC)
# File not found
# Quality of total  of  Lipid(POPC)
# File not found
# Quality of total  of  Lipid(DOPC)
# File not found
# Quality of total  of  Lipid(PYPC)
# File not found
# Quality of total  of  Lipid(TMCL)
# File not found
# Quality of total  of  Lipid(C30)
# File not found
# Quality of total  of  Lipid(SOPC)
# File not found
# Quality of total  of  Lipid(DCHOL)
# File not found
# Quality of total  of  Lipid(TLCL_0H)
# File not found
# Quality of total  of  Lipid(CER180)
# File not found
# Quality of total  of  Lipid(DEPC)
# File not found
# Quality of total  of  Lipid(CER)
# File not found
# Quality of total  of  Lipid(DSPC)
# File not found
# Quality of total  of  Lipid(DAPC)
# File not found
# Quality of total  of  Lipid(SAPI)
# File not found
# Quality of total  of  Lipid(SLPI)
# File not found
# Quality of total  of  Lipid(DLPC)
# File not found
# Quality of total  of  Lipid(DYPC)
# File not found
# Quality of total  of  Lipid(DPPGK)
# File not found
# Quality of total  of  Lipid(DHMDMAB)
# File not found
# Quality of total  of  Lipid(SAPI24)
# File not found
# Quality of total  of  Lipid(DMTAP)
# File not found
# Quality of total  of  Lipid(DPPE)
# File not found
# Quality of total  of  Lipid(GM1)
# File not found
# Quality of total  of  Lipid(POPS)
# File not found
# Quality of total  of  Lipid(CHOL)
# File not found
# Quality of total  of  Lipid(PAzePCprot)
# File not found
# Quality of total  of  Lipid(BOG)
# File not found
# Quality of total  of  Lipid(POPI)
# File not found
# Quality of total  of  Lipid(TOCL)
# File not found
# Quality of total  of  Lipid(DOG)
# File not found
# Quality of sn-1  of  Lipid(DRPC)
# File not found
# Quality of sn-1  of  Lipid(DOPE)
# File not found
# Quality of sn-1  of  Lipid(SM16)
# File not found
# Quality of sn-1  of  Lipid(SLiPC)
# File not found
# Quality of sn-1  of  Lipid(SDPE)
# File not found
# Quality of sn-1  of  Lipid(SDG)
# File not found
# Quality of sn-1  of  Lipid(DMPC)
# File not found
# Quality of sn-1  of  Lipid(GB3)
# File not found
# Quality of sn-1  of  Lipid(PAzePCdeprot)
# File not found
# Quality of sn-1  of  Lipid(POPG)
# File not found
# Quality of sn-1  of  Lipid(SAPI25)
# File not found
# Quality of sn-1  of  Lipid(DOPS)
# File not found
# Quality of sn-1  of  Lipid(SM18)
# File not found
# Quality of sn-1  of  Lipid(DLIPC)
# File not found
# Quality of sn-1  of  Lipid(DPPG)
# File not found
# Quality of sn-1  of  Lipid(DDOPC)
# File not found
# Quality of sn-1  of  Lipid(POPE)
# File not found
# Quality of sn-1  of  Lipid(DPPC)
# File not found
# Quality of sn-1  of  Lipid(POPC)
# File not found
# Quality of sn-1  of  Lipid(DOPC)
# File not found
# Quality of sn-1  of  Lipid(PYPC)
# File not found
# Quality of sn-1  of  Lipid(TMCL)
# File not found
# Quality of sn-1  of  Lipid(C30)
# File not found
# Quality of sn-1  of  Lipid(SOPC)
# File not found
# Quality of sn-1  of  Lipid(DCHOL)
# File not found
# Quality of sn-1  of  Lipid(TLCL_0H)
# File not found
# Quality of sn-1  of  Lipid(CER180)
# File not found
# Quality of sn-1  of  Lipid(DEPC)
# File not found
# Quality of sn-1  of  Lipid(CER)
# File not found
# Quality of sn-1  of  Lipid(DSPC)
# File not found
# Quality of sn-1  of  Lipid(DAPC)
# File not found
# Quality of sn-1  of  Lipid(SAPI)
# File not found
# Quality of sn-1  of  Lipid(SLPI)
# File not found
# Quality of sn-1  of  Lipid(DLPC)
# File not found
# Quality of sn-1  of  Lipid(DYPC)
# File not found
# Quality of sn-1  of  Lipid(DPPGK)
# File not found
# Quality of sn-1  of  Lipid(DHMDMAB)
# File not found
# Quality of sn-1  of  Lipid(SAPI24)
# File not found
# Quality of sn-1  of  Lipid(DMTAP)
# File not found
# Quality of sn-1  of  Lipid(DPPE)
# File not found
# Quality of sn-1  of  Lipid(GM1)
# File not found
# Quality of sn-1  of  Lipid(POPS)
# File not found
# Quality of sn-1  of  Lipid(CHOL)
# File not found
# Quality of sn-1  of  Lipid(PAzePCprot)
# File not found
# Quality of sn-1  of  Lipid(BOG)
# File not found
# Quality of sn-1  of  Lipid(POPI)
# File not found
# Quality of sn-1  of  Lipid(TOCL)
# File not found
# Quality of sn-1  of  Lipid(DOG)
# File not found
# Quality of sn-2  of  Lipid(DRPC)
# File not found
# Quality of sn-2  of  Lipid(DOPE)
# File not found
# Quality of sn-2  of  Lipid(SM16)
# File not found
# Quality of sn-2  of  Lipid(SLiPC)
# File not found
# Quality of sn-2  of  Lipid(SDPE)
# File not found
# Quality of sn-2  of  Lipid(SDG)
# File not found
# Quality of sn-2  of  Lipid(DMPC)
# File not found
# Quality of sn-2  of  Lipid(GB3)
# File not found
# Quality of sn-2  of  Lipid(PAzePCdeprot)
# File not found
# Quality of sn-2  of  Lipid(POPG)
# File not found
# Quality of sn-2  of  Lipid(SAPI25)
# File not found
# Quality of sn-2  of  Lipid(DOPS)
# File not found
# Quality of sn-2  of  Lipid(SM18)
# File not found
# Quality of sn-2  of  Lipid(DLIPC)
# File not found
# Quality of sn-2  of  Lipid(DPPG)
# File not found
# Quality of sn-2  of  Lipid(DDOPC)
# File not found
# Quality of sn-2  of  Lipid(POPE)
# File not found
# Quality of sn-2  of  Lipid(DPPC)
# File not found
# Quality of sn-2  of  Lipid(POPC)
# File not found
# Quality of sn-2  of  Lipid(DOPC)
# File not found
# Quality of sn-2  of  Lipid(PYPC)
# File not found
# Quality of sn-2  of  Lipid(TMCL)
# File not found
# Quality of sn-2  of  Lipid(C30)
# File not found
# Quality of sn-2  of  Lipid(SOPC)
# File not found
# Quality of sn-2  of  Lipid(DCHOL)
# File not found
# Quality of sn-2  of  Lipid(TLCL_0H)
# File not found
# Quality of sn-2  of  Lipid(CER180)
# File not found
# Quality of sn-2  of  Lipid(DEPC)
# File not found
# Quality of sn-2  of  Lipid(CER)
# File not found
# Quality of sn-2  of  Lipid(DSPC)
# File not found
# Quality of sn-2  of  Lipid(DAPC)
# File not found
# Quality of sn-2  of  Lipid(SAPI)
# File not found
# Quality of sn-2  of  Lipid(SLPI)
# File not found
# Quality of sn-2  of  Lipid(DLPC)
# File not found
# Quality of sn-2  of  Lipid(DYPC)
# File not found
# Quality of sn-2  of  Lipid(DPPGK)
# File not found
# Quality of sn-2  of  Lipid(DHMDMAB)
# File not found
# Quality of sn-2  of  Lipid(SAPI24)
# File not found
# Quality of sn-2  of  Lipid(DMTAP)
# File not found
# Quality of sn-2  of  Lipid(DPPE)
# File not found
# Quality of sn-2  of  Lipid(GM1)
# File not found
# Quality of sn-2  of  Lipid(POPS)
# File not found
# Quality of sn-2  of  Lipid(CHOL)
# File not found
# Quality of sn-2  of  Lipid(PAzePCprot)
# File not found
# Quality of sn-2  of  Lipid(BOG)
# File not found
# Quality of sn-2  of  Lipid(POPI)
# File not found
# Quality of sn-2  of  Lipid(TOCL)
# File not found
# Quality of sn-2  of  Lipid(DOG)
# File not found
# Quality of headgroup  of  Lipid(DRPC)
# File not found
# Quality of headgroup  of  Lipid(DOPE)
# File not found
# Quality of headgroup  of  Lipid(SM16)
# File not found
# Quality of headgroup  of  Lipid(SLiPC)
# File not found
# Quality of headgroup  of  Lipid(SDPE)
# File not found
# Quality of headgroup  of  Lipid(SDG)
# File not found
# Quality of headgroup  of  Lipid(DMPC)
# File not found
# Quality of headgroup  of  Lipid(GB3)
# File not found
# Quality of headgroup  of  Lipid(PAzePCdeprot)
# File not found
# Quality of headgroup  of  Lipid(POPG)
# File not found
# Quality of headgroup  of  Lipid(SAPI25)
# File not found
# Quality of headgroup  of  Lipid(DOPS)
# File not found
# Quality of headgroup  of  Lipid(SM18)
# File not found
# Quality of headgroup  of  Lipid(DLIPC)
# File not found
# Quality of headgroup  of  Lipid(DPPG)
# File not found
# Quality of headgroup  of  Lipid(DDOPC)
# File not found
# Quality of headgroup  of  Lipid(POPE)
# File not found
# Quality of headgroup  of  Lipid(DPPC)
# File not found
# Quality of headgroup  of  Lipid(POPC)
# File not found
# Quality of headgroup  of  Lipid(DOPC)
# File not found
# Quality of headgroup  of  Lipid(PYPC)
# File not found
# Quality of headgroup  of  Lipid(TMCL)
# File not found
# Quality of headgroup  of  Lipid(C30)
# File not found
# Quality of headgroup  of  Lipid(SOPC)
# File not found
# Quality of headgroup  of  Lipid(DCHOL)
# File not found
# Quality of headgroup  of  Lipid(TLCL_0H)
# File not found
# Quality of headgroup  of  Lipid(CER180)
# File not found
# Quality of headgroup  of  Lipid(DEPC)
# File not found
# Quality of headgroup  of  Lipid(CER)
# File not found
# Quality of headgroup  of  Lipid(DSPC)
# File not found
# Quality of headgroup  of  Lipid(DAPC)
# File not found
# Quality of headgroup  of  Lipid(SAPI)
# File not found
# Quality of headgroup  of  Lipid(SLPI)
# File not found
# Quality of headgroup  of  Lipid(DLPC)
# File not found
# Quality of headgroup  of  Lipid(DYPC)
# File not found
# Quality of headgroup  of  Lipid(DPPGK)
# File not found
# Quality of headgroup  of  Lipid(DHMDMAB)
# File not found
# Quality of headgroup  of  Lipid(SAPI24)
# File not found
# Quality of headgroup  of  Lipid(DMTAP)
# File not found
# Quality of headgroup  of  Lipid(DPPE)
# File not found
# Quality of headgroup  of  Lipid(GM1)
# File not found
# Quality of headgroup  of  Lipid(POPS)
# File not found
# Quality of headgroup  of  Lipid(CHOL)
# File not found
# Quality of headgroup  of  Lipid(PAzePCprot)
# File not found
# Quality of headgroup  of  Lipid(BOG)
# File not found
# Quality of headgroup  of  Lipid(POPI)
# File not found
# Quality of headgroup  of  Lipid(TOCL)
# File not found
# Quality of headgroup  of  Lipid(DOG)
# File not found

# %% [markdown]
# # Show form factor ranking only for systems with a specific lipid (cholesterol as an example)

# %%
### This is showing the ranking only for systems containing cholesterol

FFrankingPath = os.path.join(
    NMLDB_ROOT_PATH, 'Data', 'Ranking', 'SYSTEM_FormFactor_Ranking.json')
lipid = 'CHOL'

with open(FFrankingPath) as json_file:
    FFranking = json.load(json_file)

NewRank = []
for i in FFranking:
    if lipid in i['system']['COMPOSITION']:
        NewRank.append(i)
   
showTable(NewRank,'TotalQuality')
# Out:
#     FFQuality                                        Forcefield  \
# 0        0.07                                           Lipid17
# 1        0.17                                           Lipid17
# 2        0.17                                           Lipid17
# 3        0.23                                            MacRog
# 4        0.23                                            MacRog
# 5        0.26                                            MacRog
# 6        0.26                                           Lipid17
# 7        0.27  Berger and Modified Höltje model for cholesterol
# 8        0.33  Berger and Modified Höltje model for cholesterol
# 9        0.36                                            MacRog
# 10       0.36                                            MacRog
# 11       0.44                                           Slipids
# 12       0.44                                           Slipids
# 13       0.46                                           Lipid17
# 14       0.46                                           Lipid17
# 15       0.54                                           Slipids
# 16       0.63                                            MacRog
# 17       0.73                                           Slipids
# 18       0.73                                           Slipids
# 19       0.75  Berger and Modified Höltje model for cholesterol
# 20       0.93                                           Slipids
# 21       1.14                                          CHARMM36
# 22       1.14                                          CHARMM36
# 23       1.24                                          CHARMM36
# 24       1.29  Berger and Modified Höltje model for cholesterol
# 25       1.43                                          CHARMM36
# 26       1.53                                          CHARMM36
# 27       1.53                                          CHARMM36
# 28       1.53                                           Lipid17
# 29       1.53                                           Lipid17
# 30       1.63                                           Slipids
# 31       1.63                                           Slipids
# 32       1.73                                           Slipids
# 33       1.73                                           Lipid17
# 34       1.75                                           Slipids
# 35       1.75                                           Slipids
# 36       1.75                                           Slipids
# 37       2.03                                            MacRog
# 38       2.03                                            MacRog
# 39       2.03                                            MacRog
# 40       2.05                                            MacRog
# 41       2.05                                            MacRog
# 42       2.05                                            MacRog
# 43       2.13                                          CHARMM36
# 44       2.23                                          CHARMM36
# 45       2.23                                          CHARMM36
# 46       2.25                                          CHARMM36
# 47       2.25                                          CHARMM36
# 48       2.25                                           Lipid17
# 49       2.25                                          CHARMM36
# 50       2.35                                           Lipid17
# 51       2.35                                           Lipid17
# 52       3.39                                           slipids
#
#         Molecules Number of molecules  Temperature   ID  headgroup  tails  \
# 0   POPC:SOL:CHOL        (64:4000:16)       298.15  662        NaN    NaN
# 1   POPC:SOL:CHOL      (256:16000:64)       298.15  666        NaN    NaN
# 2   POPC:SOL:CHOL    (1024:64000:256)       298.15  667        NaN    NaN
# 3   POPC:SOL:CHOL    (1024:64000:256)       298.15  677        NaN    NaN
# 4   POPC:SOL:CHOL      (256:16000:64)       298.15  706        NaN    NaN
# 5   POPC:SOL:CHOL         (64:3600:8)       298.15  665        NaN    NaN
# 6   POPC:SOL:CHOL         (64:3600:8)       298.15  680        NaN    NaN
# 7   POPC:CHOL:SOL       (110:18:8481)       298.00  589       0.02   0.40
# 8   POPC:CHOL:SOL        (84:44:6794)       298.00  206       0.04   0.07
# 9   POPC:SOL:CHOL      (256:14400:32)       298.15  695        NaN    NaN
# 10  POPC:SOL:CHOL    (1024:57600:128)       298.15  660        NaN    NaN
# 11  POPC:SOL:CHOL      (256:14400:32)       298.15  681        NaN    NaN
# 12  POPC:SOL:CHOL    (1024:57600:128)       298.15  697        NaN    NaN
# 13  POPC:SOL:CHOL    (1024:57600:128)       298.15  663        NaN    NaN
# 14  POPC:SOL:CHOL      (256:14400:32)       298.15  689        NaN    NaN
# 15  POPC:SOL:CHOL         (64:3600:8)       298.15  672        NaN    NaN
# 16  POPC:SOL:CHOL        (64:4000:16)       298.15  702        NaN    NaN
# 17  POPC:SOL:CHOL    (1024:64000:256)       298.15  691        NaN    NaN
# 18  POPC:SOL:CHOL      (256:16000:64)       298.15  687        NaN    NaN
# 19  POPC:CHOL:SOL        (120:8:7290)       298.00  305       0.02   0.58
# 20  POPC:SOL:CHOL        (64:4000:16)       298.15  692        NaN    NaN
# 21  POPC:CHOL:SOL      (256:32:14400)       298.15  119        NaN    NaN
# 22  POPC:CHOL:SOL    (1024:128:57600)       298.15  426        NaN    NaN
# 23  POPC:CHOL:SOL         (64:8:3600)       298.15  109        NaN    NaN
# 24  POPC:CHOL:SOL       (64:64:10314)       298.00  299       0.02   0.09
# 25  POPC:CHOL:SOL    (1024:256:64000)       298.15   88        NaN    NaN
# 26  POPC:CHOL:SOL        (64:16:4000)       298.15  525        NaN    NaN
# 27  POPC:CHOL:SOL      (256:64:16000)       298.15   72        NaN    NaN
# 28  POPC:SOL:CHOL     (256:20800:160)       298.15  694        NaN    NaN
# 29  POPC:SOL:CHOL    (1024:83200:640)       298.15  673        NaN    NaN
# 30  POPC:SOL:CHOL     (256:20800:160)       298.15  668        NaN    NaN
# 31  POPC:SOL:CHOL    (1024:83200:640)       298.15  670        NaN    NaN
# 32  POPC:SOL:CHOL        (64:5200:40)       298.15  661        NaN    NaN
# 33  POPC:SOL:CHOL        (64:5200:40)       298.15  688        NaN    NaN
# 34  POPC:SOL:CHOL        (64:6000:56)       298.15  703        NaN    NaN
# 35  POPC:SOL:CHOL     (256:24000:224)       298.15  712        NaN    NaN
# 36  POPC:SOL:CHOL    (1024:96000:896)       298.15  682        NaN    NaN
# 37  POPC:SOL:CHOL     (256:20800:160)       298.15  679        NaN    NaN
# 38  POPC:SOL:CHOL        (64:5200:40)       298.15  716        NaN    NaN
# 39  POPC:SOL:CHOL    (1024:83200:640)       298.15  698        NaN    NaN
# 40  POPC:SOL:CHOL        (64:6000:56)       298.15  704        NaN    NaN
# 41  POPC:SOL:CHOL     (256:24000:224)       298.15  699        NaN    NaN
# 42  POPC:SOL:CHOL    (1024:96000:896)       298.15  671        NaN    NaN
# 43  POPC:CHOL:SOL    (1024:640:83200)       298.15  550        NaN    NaN
# 44  POPC:CHOL:SOL     (256:160:20800)       298.15  275        NaN    NaN
# 45  POPC:CHOL:SOL        (64:40:5200)       298.15  620        NaN    NaN
# 46  POPC:CHOL:SOL     (256:224:24000)       298.15  166        NaN    NaN
# 47  POPC:CHOL:SOL    (1024:896:96000)       298.15  543        NaN    NaN
# 48  POPC:SOL:CHOL    (1024:96000:896)       298.15  717        NaN    NaN
# 49  POPC:CHOL:SOL        (64:56:6000)       298.15   91        NaN    NaN
# 50  POPC:SOL:CHOL     (256:24000:224)       298.15  714        NaN    NaN
# 51  POPC:SOL:CHOL        (64:6000:56)       298.15  707        NaN    NaN
# 52  CHOL:POPC:SOL     (256:256:20334)       298.00   82       0.18   0.20
#
#     total
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7    0.27
# 8    0.06
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19   0.39
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24   0.08
# 25    NaN
# 26    NaN
# 27    NaN
# 28    NaN
# 29    NaN
# 30    NaN
# 31    NaN
# 32    NaN
# 33    NaN
# 34    NaN
# 35    NaN
# 36    NaN
# 37    NaN
# 38    NaN
# 39    NaN
# 40    NaN
# 41    NaN
# 42    NaN
# 43    NaN
# 44    NaN
# 45    NaN
# 46    NaN
# 47    NaN
# 48    NaN
# 49    NaN
# 50    NaN
# 51    NaN
# 52   0.21

# %% [markdown]
# # Show sn-1 ranking only for systems with POPC and CHOLESTEROL

# %%
### This is showing the ranking only for systems containing POPC and cholesterol

FFrankingPath = os.path.join(
    NMLDB_ROOT_PATH, 'Data', 'Ranking', 'POPC_sn-1_Ranking.json')
lipid = 'CHOL'

with open(FFrankingPath) as json_file:
    FFranking = json.load(json_file)

NewRank = []
for i in FFranking:
    if lipid in i['system']['COMPOSITION']:
        NewRank.append(i)
   
showTable(NewRank,'POPC')
# Out:
#    sn-1  sn-2  headgroup  total  \
# 0  0.82  0.50       0.03   0.45
# 1  0.60  0.49       0.71   0.60
# 2  0.37  0.71       0.03   0.37
# 3  0.17  0.24       0.07   0.16
# 4  0.12  0.18       0.08   0.13
# 5  0.08  0.26       0.10   0.15
#
#                                          Forcefield      Molecules  \
# 0  Berger and Modified Höltje model for cholesterol  POPC:CHOL:SOL
# 1                                           slipids  CHOL:POPC:SOL
# 2  Berger and Modified Höltje model for cholesterol  POPC:CHOL:SOL
# 3  Berger and Modified Höltje model for cholesterol  POPC:CHOL:SOL
# 4  Berger and Modified Höltje model for cholesterol  POPC:CHOL:SOL
# 5  Berger and Modified Höltje model for cholesterol  POPC:CHOL:SOL
#
#   Number of molecules  Temperature   ID
# 0        (120:8:7290)          298  305
# 1     (256:256:20334)          298   82
# 2       (110:18:8481)          298  589
# 3       (64:64:10314)          298  299
# 4        (50:78:5782)          298   15
# 5        (84:44:6794)          298  206
